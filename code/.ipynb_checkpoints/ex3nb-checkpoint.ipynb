# %%
#Import GEOPROPY library
import geopropy as gpp
#Execute main function
lit_table="Borehole_subunits"
bore_ids=[111,112,113,114,115,116,117,118,119]
database_dir=r"'your repo'\Examples\Synthetic3\synthetic_3.mdb"

gpp.cross_section(database_dir, bore_ids, lit_table)
#'jumptomanual'
#[ [ [ [166,166,-71 ,'116'],29,33 ] ,'','new_points'],[ 33,34,'same_bh_connect_right'],[ [ [173,173,-75 ,'116'],30,34 ] ,'','new_points']]
#[3,'SEPARATE',9,15,14,'SEPARATE',8,5,11,'SEPARATE',17]
#[4,'SEPARATE',10,16,13,'SEPARATE',7,6,12,'SEPARATE',18]
# Out:
# ######### Pre-processing... #########
# ########## Pre-processing finished #########
# Time: 0.00200009346008
#
#
#
#
# ######### Reading data... #########
# ######### Reading data finished #########
# Time: 0.066999912262
#
#
#
#
# ######### 3D plane calculator, Projecting surface points, Generating Topography and guide bottom boundary... #########
# ######### 3D plane calculator, Projecting surface points, Generating Topography and guide bottom boundary finished #########
# Time: 0.000999927520752
#
#
#
#
# ######### Point extraction... #########
# ######### Point extraction finished #########
# Time: 0.00200009346008
#
#
#
#
# ####topography reading data and processing####
# ####topography reading data and processing finished####
# Time: 0.00200009346008
#
#
#
#
# ######### Critical zones processing... #########
#
# ##########################################################################################
# ##########################################################################################
# ##########################################################################################
# Structure Determination
# priority: 4
# priority_type intrusion
#
# ###########
# zone box:
# |   X |   Y |   Z |
# |-----+-----+-----|
# | 180 | 180 | -38 |
# | 230 | 230 | -38 |
# | 230 | 230 | -63 |
# | 180 | 180 | -63 |
# #############################################
# ### RELATED FAULTS ###
# No related fault detected
#
# #############################################
# ### ZONE INFORMATION ###
#
# | POINT_TYPE      |   BOREHOLE_ID |   BOREHOLE_INDEX | [X,Y,Z]               | POLARITY   |  POINT SIT.   |   POINT_ID |
# |-----------------+---------------+------------------+-----------------------+------------+---------------+------------|
# | Borehole_points |           117 |                8 | [180.0, 180.0, -55.0] | Normal     | Not Connected |         29 |
# | Borehole_points |           117 |                8 | [180.0, 180.0, -63.0] | Normal     | Not Connected |         30 |
# | Borehole_points |           118 |                9 | [230.0, 230.0, -38.0] | Normal     | Not Connected |         33 |
# | Borehole_points |           118 |                9 | [230.0, 230.0, -63.0] | Normal     | Not Connected |         34 |
#
# #######################################################################
# ################# Stage 2: Semi-Automatic ############################
# #######################################################################
#
# please introduce consecutive POINT_IDs that you wish to connect in form of a list.
#  In case the critical zone consist of more than one part, write 'SEPARATE' between POINT_IDs.
#  Note that the introduced points have to follow the borehole arrangement
#
# In case this stage preferred to be done manually, Type:'jumptomanual'
#
# EXAMPLE: [25,26,37,38,'SEPARATE',45,46,'SEPARATE',65,68] or 'jumptomanual'
#
# Enter the POINT_ID list:'jumptomanual'
#
# #######################################################################
# #################Additional data needed, Stage 3:Manual ################
# #######################################################################
#
# There are points which are not connected from any side to any borehole. please specify how they have to connect. Use the instruction below:
#
# priority: 4
#
# priority_type intrusion
#
# IMPORTANT NOTE: FOLLOWING SAMPLE POINT INFORMATION IS JUST FOR GUIDING THE USER, DO NOT INTRODUCE THE BOREHOLE IDS IBASED ON 'ZONE INFORMATION'. INTRODUCE IDs AVAILABLE IN 'Disconnected sample points'
#
# ### ZONE INFORMATION ###
#
# | POINT_TYPE      |   BOREHOLE_ID |   BOREHOLE_INDEX | [X,Y,Z]               | POLARITY   |  POINT SIT.   |   POINT_ID |
# |-----------------+---------------+------------------+-----------------------+------------+---------------+------------|
# | Borehole_points |           117 |                8 | [180.0, 180.0, -55.0] | Normal     | Not Connected |         29 |
# | Borehole_points |           117 |                8 | [180.0, 180.0, -63.0] | Normal     | Not Connected |         30 |
# | Borehole_points |           118 |                9 | [230.0, 230.0, -38.0] | Normal     | Not Connected |         33 |
# | Borehole_points |           118 |                9 | [230.0, 230.0, -63.0] | Normal     | Not Connected |         34 |
#
# ######################## 3rd STAGE GUIDE ##############################
#
# point IDs have to introduce in pairs, accompanied by a keyword that identify their situation:
#
# If both points are in 2 CONSECUTIVE borehole or surface points: [point_id 1,point_id 2, 'normal_connection'] (point_id 1 is the sample point with smaller BOREHOLE_INDEX)
#
# If both points are in the same borehole, based on the side that you want them to connect: [point_id 1,point_id 2, 'same_bh_connect_left'] or [point_id 1,point_id 2, 'same_bh_connect_right']
#
# If it is preferred that the program take care of a point: [point_id 1,'', 'user_skipped'] (NOT RECOMMENDED)
#
# If it is preferred to introduce new coordinations and point ids, every group of lines (group of lines that are connected together) have to be introduced in different lists. the coordination of the new point and the related borehole id (if new introduced point is between two boreholes, use left side borehole id  ) have to be introduced.
#
# Note that if the manual introduced structure lines going to pass the boreholes, the coordination of the point in borehole and borehole id have to be introduced .
#
# structure: [ [Coord_X,Coord_Y,Coord_Z,'BOREHOLE_ID' (string)], point_id1, point_id2, [Coord_X,Coord_Y,Coord_Z,'BOREHOLE_ID' (string)],.... ] , '' , 'new_points']. Maintain sequence of the points. Note that in this part, it is possible to use points with ids that shown before.
#
# ################Disconnected sample points##################
#
# | POINT_TYPE      |   BOREHOLE_ID |   BOREHOLE_INDEX | [X,Y,Z]               | POLARITY   |  POINT SIT.   |   POINT_ID |
# |-----------------+---------------+------------------+-----------------------+------------+---------------+------------|
# | Borehole_points |           117 |                8 | [180.0, 180.0, -55.0] | Normal     | Not Connected |         29 |
# | Borehole_points |           117 |                8 | [180.0, 180.0, -63.0] | Normal     | Not Connected |         30 |
# | Borehole_points |           118 |                9 | [230.0, 230.0, -38.0] | Normal     | Not Connected |         33 |
# | Borehole_points |           118 |                9 | [230.0, 230.0, -63.0] | Normal     | Not Connected |         34 |
#
# Enter POINT_ID list as mentioned:
#
# [ [ [ [166,166,-71 ,'116'],29,33 ] ,'','new_points'],[ 33,34,'same_bh_connect_right'],[ [ [173,173,-75 ,'116'],30,34 ] ,'','new_points']]
#
# ##########################################################################################
# ##########################################################################################
# ##########################################################################################
# Structure Determination
# priority: 3
# priority_type normal
#
# ###########
# zone box:
# |   X |   Y |   Z |
# |-----+-----+-----|
# |  90 |  90 | -10 |
# | 130 | 130 | -10 |
# | 130 | 130 | -55 |
# |  90 |  90 | -55 |
# #############################################
# ### RELATED FAULTS ###
# fault prioroty: 6
# fault points:
# |   BOREHOLE_ID | [X,Y,Z]               |   POINT_ID |
# |---------------+-----------------------+------------|
# |           112 | [90.0, 90.0, -47.0]   |         39 |
# |           113 | [110.0, 110.0, -20.0] |         41 |
#
# #############################################
# ### ZONE INFORMATION ###
#
# | POINT_TYPE      |   BOREHOLE_ID |   BOREHOLE_INDEX | [X,Y,Z]               | POLARITY   |  POINT SIT.   |   POINT_ID |
# |-----------------+---------------+------------------+-----------------------+------------+---------------+------------|
# | Borehole_points |           111 |                2 | [70.0, 70.0, -50.0]   | Normal     | Not Connected |          3 |
# | Borehole_points |           112 |                3 | [90.0, 90.0, -10.0]   | Normal     | Not Connected |          5 |
# | Borehole_points |           112 |                3 | [90.0, 90.0, -25.0]   | Reverse    | Not Connected |          8 |
# | Borehole_points |           112 |                3 | [90.0, 90.0, -55.0]   | Normal     | Not Connected |          9 |
# | Borehole_points |           113 |                4 | [110.0, 110.0, -10.0] | Normal     | Not Connected |         11 |
# | Borehole_points |           113 |                4 | [110.0, 110.0, -35.0] | Reverse    | Not Connected |         14 |
# | Borehole_points |           113 |                4 | [110.0, 110.0, -55.0] | Normal     | Not Connected |         15 |
# | Borehole_points |           114 |                5 | [130.0, 130.0, -13.0] | Normal     | Not Connected |         17 |
#
# #######################################################################
# ################# Stage 2: Semi-Automatic ############################
# #######################################################################
#
# please introduce consecutive POINT_IDs that you wish to connect in form of a list.
#  In case the critical zone consist of more than one part, write 'SEPARATE' between POINT_IDs.
#  Note that the introduced points have to follow the borehole arrangement
#
# In case this stage preferred to be done manually, Type:'jumptomanual'
#
# EXAMPLE: [25,26,37,38,'SEPARATE',45,46,'SEPARATE',65,68] or 'jumptomanual'
# Enter the POINT_ID list:[3,'SEPARATE',9,15,14,'SEPARATE',8,5,11,'SEPARATE',17]
#
# ##########################################################################################
# ##########################################################################################
# ##########################################################################################
# Structure Determination
# priority: 2
# priority_type normal
#
# ###########
# zone box:
# |   X |   Y |   Z |
# |-----+-----+-----|
# |  90 |  90 | -15 |
# | 130 | 130 | -15 |
# | 130 | 130 | -60 |
# |  90 |  90 | -60 |
# #############################################
# ### RELATED FAULTS ###
# fault prioroty: 6
# fault points:
# |   BOREHOLE_ID | [X,Y,Z]               |   POINT_ID |
# |---------------+-----------------------+------------|
# |           112 | [90.0, 90.0, -47.0]   |         39 |
# |           113 | [110.0, 110.0, -20.0] |         41 |
#
# #############################################
# ### ZONE INFORMATION ###
#
# | POINT_TYPE      |   BOREHOLE_ID |   BOREHOLE_INDEX | [X,Y,Z]               | POLARITY   |  POINT SIT.   |   POINT_ID |
# |-----------------+---------------+------------------+-----------------------+------------+---------------+------------|
# | Borehole_points |           111 |                2 | [70.0, 70.0, -56.0]   | Normal     | Not Connected |          4 |
# | Borehole_points |           112 |                3 | [90.0, 90.0, -15.0]   | Normal     | Not Connected |          6 |
# | Borehole_points |           112 |                3 | [90.0, 90.0, -20.0]   | Reverse    | Not Connected |          7 |
# | Borehole_points |           112 |                3 | [90.0, 90.0, -60.0]   | Normal     | Not Connected |         10 |
# | Borehole_points |           113 |                4 | [110.0, 110.0, -15.0] | Normal     | Not Connected |         12 |
# | Borehole_points |           113 |                4 | [110.0, 110.0, -30.0] | Reverse    | Not Connected |         13 |
# | Borehole_points |           113 |                4 | [110.0, 110.0, -60.0] | Normal     | Not Connected |         16 |
# | Borehole_points |           114 |                5 | [130.0, 130.0, -17.0] | Normal     | Not Connected |         18 |
#
# #######################################################################
# ################# Stage 2: Semi-Automatic ############################
# #######################################################################
#
# please introduce consecutive POINT_IDs that you wish to connect in form of a list.
#  In case the critical zone consist of more than one part, write 'SEPARATE' between POINT_IDs.
#  Note that the introduced points have to follow the borehole arrangement
#
# In case this stage preferred to be done manually, Type:'jumptomanual'
#
# EXAMPLE: [25,26,37,38,'SEPARATE',45,46,'SEPARATE',65,68] or 'jumptomanual'
#
# Enter the POINT_ID list:[4,'SEPARATE',10,16,13,'SEPARATE',7,6,12,'SEPARATE',18]
# ######### Critical zones processing finish #########
# Time: 26.3399999142
#
#
#
#
# ######### Generating automatic definite lines... #########
# ######### Generating automatic definite lines finished #########
# Time: 0.00399994850159
#
#
#
#
# ######### Angle processing... #########
# ######### Angle processing finished #########
# Time: 0.00100016593933
#
#
#
#
# ######### Automatic structure completion... #########
# delete 2 3 [3, 'normal', None, [70.0, 70.0, -50.0], [90.0, 90.0, -55.0]]
# delete 2 3 [2, 'normal', None, [70.0, 70.0, -56.0], [90.0, 90.0, -60.0]]
# delete 4 5 [2, 'normal', None, [110.0, 110.0, -15.0], [130.0, 130.0, -17.0]]
# delete 4 5 [3, 'normal', None, [110.0, 110.0, -10.0], [130.0, 130.0, -13.0]]
# ######### Automatic structure completion finished #########
# Time: 0.0199999809265
#
#
#
#
# ######### Ultimate bottom boundary... #########
# ######### Ultimate bottom boundary finished #########
# Time: 7.58899998665
#
#
#
#
# ######### Creating 3D point and layers (polylines) database... #########
# ######### Creating 3D point and layers (polylines) database finished #########
# Time: 55.5980000496
#
#
#
#
# ######### 3D to 2D Convertion, polygon determiner, 2D cross-section maker, 3D polygon database generator... #########
# ######### 3D to 2D Convertion, polygon determiner, 2D cross-section maker, 3D polygon database generator finished #########
# Time: 52.1040000916
#
#
#
#
# Total time:
# 147.111000061
